# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
data =  pd.read_csv("Data.csv")
data.head()
# Out:
#    Unnamed: 0                                              Rowid  Year  \
# 0           0                2019~11~JOB01~JOB~DISTYPE~SELFDIS~~  2019
# 1           1                 2019~11~JOB02~JOB~DISTYPE~MOBDIS~~  2019
# 2           2  2019~11~PAGUIDE02~PAGUIDE~DISSTAT~DISABL~SEX~GENF  2019
# 3           3         2019~11~EDUCATE01~EDUCATE~DISTYPE~INDDIS~~  2019
# 4           4     2019~11~YESNO02~HEALTH~DISSTAT~DISABL~SEX~GENM  2019
#
#   LocationAbbr          LocationDesc DataSource                   Category  \
# 0           DC  district of columbia      BRFSS               Demographics
# 1           DC  district of columbia      BRFSS               Demographics
# 2           DC  district of columbia      BRFSS   Health Risks & Behaviors
# 3           DC  district of columbia      BRFSS               Demographics
# 4           DC  district of columbia      BRFSS  General Health Conditions
#
#                                            Indicator  \
# 0  Employment status among adults 18 years of age...
# 1  Employment status among adults 18 years of age...
# 2  Meeting the physical activity guidelines among...
# 3  Education level among adults 18 years of age o...
# 4  Fair or poor self-rated health among adults 18...
#
#                    Response Data_Value_Unit  ... IndicatorID  Geolocation  \
# 0                  Employed               %  ...         JOB          NaN
# 1               Out of Work               %  ...         JOB          NaN
# 2        Meets Aerobic Only               %  ...     PAGUIDE          NaN
# 3  Some High School or Less               %  ...     EDUCATE          NaN
# 4                        No               %  ...      HEALTH          NaN
#
#    LocationID ResponseID DataValueTypeID  StratificationCategoryID1  \
# 0          11      JOB01      AGEADJPREV                    DISTYPE
# 1          11      JOB02      AGEADJPREV                    DISTYPE
# 2          11  PAGUIDE02      AGEADJPREV                    DISSTAT
# 3          11  EDUCATE01      AGEADJPREV                    DISTYPE
# 4          11    YESNO02      AGEADJPREV                    DISSTAT
#
#    StratificationID1  StratificationCategoryID2  StratificationID2  \
# 0            SELFDIS                        NaN                NaN
# 1             MOBDIS                        NaN                NaN
# 2             DISABL                        SEX               GENF
# 3             INDDIS                        NaN                NaN
# 4             DISABL                        SEX               GENM
#
#   Obesity_Value
# 0          0.24
# 1          0.24
# 2          0.24
# 3          0.24
# 4          0.24
#
# [5 rows x 34 columns]

# %% [markdown]
#  # Linear Regression with Categorical Encoding:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Selecting features and target variable
X = data[['StratificationCategory1', 'Stratification1',
          'LocationDesc', 'LocationAbbr', 'Response', 'Category', 'Indicator']]
y = data['Obesity_Value']  # Target variable

# Perform one-hot encoding on categorical columns
X_encoded = pd.get_dummies(X)

# Train-test split (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on test set
y_pred = model.predict(X_test)

# Model performance assessment
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")
# Out:
# R-squared: 0.8705669831130239

# %%
from lazypredict.Supervised import LazyRegressor
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

# %%
models
# Out:
#                                                               Adjusted R-Squared  \
# Model
# ElasticNetCV                                                                0.84
# LassoCV                                                                     0.84
# BayesianRidge                                                               0.83
# RidgeCV                                                                     0.83
# Ridge                                                                       0.83
# HuberRegressor                                                              0.83
# LGBMRegressor                                                               0.83
# HistGradientBoostingRegressor                                               0.83
# LassoLarsIC                                                                 0.83
# LassoLarsCV                                                                 0.83
# LinearRegression                                                            0.83
# TransformedTargetRegressor                                                  0.83
# XGBRegressor                                                                0.82
# RandomForestRegressor                                                       0.79
# BaggingRegressor                                                            0.77
# TweedieRegressor                                                            0.71
# GammaRegressor                                                              0.71
# ExtraTreesRegressor                                                         0.70
# GradientBoostingRegressor                                                   0.70
# OrthogonalMatchingPursuit                                                   0.69
# OrthogonalMatchingPursuitCV                                                 0.69
# DecisionTreeRegressor                                                       0.69
# ExtraTreeRegressor                                                          0.69
# NuSVR                                                                       0.68
# LarsCV                                                                      0.67
# LinearSVR                                                                   0.67
# KNeighborsRegressor                                                         0.58
# PoissonRegressor                                                            0.42
# AdaBoostRegressor                                                          -0.18
# Lasso                                                                      -0.28
# ElasticNet                                                                 -0.28
# DummyRegressor                                                             -0.28
# LassoLars                                                                  -0.28
# SVR                                                                        -0.28
# PassiveAggressiveRegressor                                                 -2.43
# SGDRegressor                                                              -14.01
# MLPRegressor                                                              -24.58
# GaussianProcessRegressor                                                  -57.31
# KernelRidge                                                               -75.04
# RANSACRegressor                                  -147246952440171742558683136.00
# Lars                          -5853058468202084968070494925609560584139042803...
#
#                                                                        R-Squared  \
# Model
# ElasticNetCV                                                                0.87
# LassoCV                                                                     0.87
# BayesianRidge                                                               0.87
# RidgeCV                                                                     0.87
# Ridge                                                                       0.87
# HuberRegressor                                                              0.87
# LGBMRegressor                                                               0.87
# HistGradientBoostingRegressor                                               0.87
# LassoLarsIC                                                                 0.87
# LassoLarsCV                                                                 0.87
# LinearRegression                                                            0.87
# TransformedTargetRegressor                                                  0.87
# XGBRegressor                                                                0.86
# RandomForestRegressor                                                       0.84
# BaggingRegressor                                                            0.82
# TweedieRegressor                                                            0.78
# GammaRegressor                                                              0.78
# ExtraTreesRegressor                                                         0.77
# GradientBoostingRegressor                                                   0.76
# OrthogonalMatchingPursuit                                                   0.76
# OrthogonalMatchingPursuitCV                                                 0.76
# DecisionTreeRegressor                                                       0.76
# ExtraTreeRegressor                                                          0.76
# NuSVR                                                                       0.75
# LarsCV                                                                      0.74
# LinearSVR                                                                   0.74
# KNeighborsRegressor                                                         0.67
# PoissonRegressor                                                            0.55
# AdaBoostRegressor                                                           0.08
# Lasso                                                                      -0.00
# ElasticNet                                                                 -0.00
# DummyRegressor                                                             -0.00
# LassoLars                                                                  -0.00
# SVR                                                                        -0.00
# PassiveAggressiveRegressor                                                 -1.67
# SGDRegressor                                                              -10.70
# MLPRegressor                                                              -18.95
# GaussianProcessRegressor                                                  -44.47
# KernelRidge                                                               -58.30
# RANSACRegressor                                  -114824306181710839185145856.00
# Lars                          -4564260017030663911633869091474139408849300463...
#
#                                                        RMSE  Time Taken
# Model
# ElasticNetCV                                           0.01        1.47
# LassoCV                                                0.01        0.51
# BayesianRidge                                          0.01        0.34
# RidgeCV                                                0.01        0.22
# Ridge                                                  0.01        0.06
# HuberRegressor                                         0.01        0.19
# LGBMRegressor                                          0.01        0.50
# HistGradientBoostingRegressor                          0.01        1.50
# LassoLarsIC                                            0.01        0.36
# LassoLarsCV                                            0.01        0.40
# LinearRegression                                       0.01        0.25
# TransformedTargetRegressor                             0.01        0.34
# XGBRegressor                                           0.02        1.29
# RandomForestRegressor                                  0.02        8.43
# BaggingRegressor                                       0.02        0.78
# TweedieRegressor                                       0.02        0.22
# GammaRegressor                                         0.02        0.09
# ExtraTreesRegressor                                    0.02       10.88
# GradientBoostingRegressor                              0.02        1.12
# OrthogonalMatchingPursuit                              0.02        0.09
# OrthogonalMatchingPursuitCV                            0.02        0.30
# DecisionTreeRegressor                                  0.02        0.21
# ExtraTreeRegressor                                     0.02        0.19
# NuSVR                                                  0.02       13.27
# LarsCV                                                 0.02        0.75
# LinearSVR                                              0.02        3.18
# KNeighborsRegressor                                    0.02        0.14
# PoissonRegressor                                       0.03        0.17
# AdaBoostRegressor                                      0.04        0.27
# Lasso                                                  0.04        0.05
# ElasticNet                                             0.04        0.04
# DummyRegressor                                         0.04        0.03
# LassoLars                                              0.04        0.11
# SVR                                                    0.04        0.13
# PassiveAggressiveRegressor                             0.07        0.13
# SGDRegressor                                           0.14        0.12
# MLPRegressor                                           0.18        1.55
# GaussianProcessRegressor                               0.28       10.62
# KernelRidge                                            0.32        1.71
# RANSACRegressor                             439494435673.89        3.10
# Lars                          87623713503572684666044416.00        0.15
